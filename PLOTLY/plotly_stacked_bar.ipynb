# %% [markdown]
# # Stacked Bar Chart

# %%
import plotly.express as px

# Load a sample dataset (a pandas DataFrame)
df = px.data.tips()

# Create a stacked bar chart
# x='day' specifies the main categories on the x-axis
# y='total_bill' specifies the values for the y-axis
# color='sex' specifies the sub-categories to stack within each bar
fig = px.bar(df, x="day", y="total_bill", color="sex", title="Total Bill by Day and Gender", barmode='stack')

# Display the figure
fig.show()
