# %% [markdown]
# # Plotly Express Bar Chart

# %%
import pandas as pd
import plotly.express as px
import os

# HTML Full Output Path
output_filename = "plotly_bar_chart.html"
full_path = os.path.join(os.getcwd(), output_filename)

x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]
df = pd.DataFrame({'x': x, 'y': y})
fig = px.bar(df, x='x', y='y')
fig.show()
fig.write_html(full_path)

# %% [markdown]
# # View the charts as HTML
# Open the saved HTML file in your web browser
#
# <a href="https://rebeccapeltz.github.io/data_analysis_code/PLOTLY/plotly_bar_chart.html" target="_blank" rel="noopener noreferrer">Bar Chart</a>
