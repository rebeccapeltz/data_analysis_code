# %% [markdown]
# # Plotly Scatter Chart

# %%
import plotly.express as px
import pandas as pd

x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]

df = pd.DataFrame({'x': x, 'y': y})
fig = px.scatter(df, x='x', y='y')

fig.show()
