# %% [markdown]
# # Plotly Scatter Chart

# %%
import plotly.express as px
import pandas as pd
import os

# HTML Full Output Path
output_filename = "plotly_scatter_chart.html"
full_path = os.path.join(os.getcwd(), output_filename)

# Load Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]

# Create DataFrame
df = pd.DataFrame({'x': x, 'y': y})

# Create Plotly Figure
fig = px.scatter(df, x='x', y='y')
fig.update_traces(marker=dict(size=18))

# Render Figure in Notebook
fig.show()
# Render Figure to an HTML File
fig.write_html(full_path)

# %% [markdown]
# # View the charts as HTML
# Open the saved HTML file in your web browser
#
# <a href="https://rebeccapeltz.github.io/data_analysis_code/PLOTLY/plotly_scatter_chart.html" target="_blank" rel="noopener noreferrer">Scatter Chart</a>
